# %% [markdown]
# ## Meeting with Mike 5/12/24
# #### Meeting number 4
# ---
#
# ### From last meeting
# In increasing priority order
# - Continuing along with gridcell specific analysis... (good progress)
# - A slightly different approach to constraing ext temps. That the change the MSE for high percentile land temps is approximatly equal to the mean shift in MSE over land
#
# $\delta T_L^x [ c_p + L_v q_L^x \alpha_L^x ] = \delta \overline{T_L} [ c_p + L_v \overline{q_L^x} \overline{\alpha_L^x} ] $
#
# $= \dfrac{\delta T_L^x}{\delta \overline{T_L}} = \dfrac{c_p + L_v \overline{q}_L \overline{\alpha}_L}{c_p + L_v q_L^x \alpha_L^x} = $ The scaling factor of land temperature at percentile x
#
# - Using Abrupt 4xCO2 simulations - PiControl vs 4xCO2 - bigger hammer
#
# - Removing the seasonal cycle and doing a similar analysis
#
# - Using global temperature change to predict extreme temp changes - we know extreme temps are sensitive to changes in ocean temperature - reasonable to assume that the change in global temperature could fairly well constrain tropical extremes
#
# <details><summary>More details here</summary>
#
# ## Plan going foreward:
# In decreasing order of priority:
# ##### Using $\delta T_{global}$ to constrain $\delta T_L^x$ - with existing imegent constraints
#
# The idea here is that there is a host of research looking into constraining global temperatures from the ECS people...
# - We also know that becasue of the observed connections between $\delta T_O$  its reasonable to assume that $\delta T_{global}$ is probably also well correlated
#
# ![image.png](attachment:e062b374-0749-4789-8fee-6a865aab298e.png)
#
# Check out sherwood for potential constraints
#
# ##### Removing the seasonal cycle to look at temperature anomalies
# - This would be a different metric but would move the analysis away from purely looking at hot summer temps
#
# ##### Looking at abrupt4xCO2
# - The idea here is to use as Mike put it - a bigger hammer to reduce the noise vs signal
# - Here we'd look at the last 20 years of the abrupt4xCO2 vs 20 years of the PiControl simulations
# - 4xCO2 are branched off the PiControl - Pi is preindustrial
#
# ##### A slightly different theory for extreme temperature response:
# We have primarily been focused on a branch of the theory that says $\delta h_L \approx \delta h_O$ ie that changes in moist static energy are equal over land and ocean
#
# However, part of the theory that Josh has been more concerned with is that $\delta h_L^x \approx \overline{h_L}$ ie that the distribution of MSE essentially just shifts to the right with a change in temperature
#
# Taking this theory through some steps:
#
# $\delta h_L^x \approx \overline{h_L} \qquad \Rightarrow  \qquad  c_p \delta T_L^x + L_v \delta q_L^x \approx c_p \delta \overline{T_L} + L_v \delta \overline{q_L}$
#
# $r_L^x = \dfrac{q^x_L}{q^{*x}} \qquad  \Rightarrow \qquad \dfrac{\delta q_L^x}{q_L^x} = \dfrac{\delta q_L^{*x}}{q^{*x}_L} + \dfrac{\delta r_L^x}{r^x_L} \qquad$   However... we can neglect the final relative humidity term here for constant relative humidity
#
# $= \alpha_L^x \delta T_L^x \qquad \Rightarrow \qquad \delta q_L^x = q_L^x \alpha_L^x \delta T_L^x \qquad$ This gives us an expression for $\delta q_L^x $ that we can pop into $c_p \delta T_L^x + L_v \delta q_L^x \approx c_p \delta \overline{T_L} + L_v \delta \overline{q_L}$
#
#
# Then we have a similar form taking shape...
#
# $\delta T_L^x [ c_p + L_v q_L^x \alpha_L^x ] = \delta \overline{T_L} [ c_p + L_v \overline{q_L^x} \overline{\alpha_L^x} ] $
#
# $= \dfrac{\delta T_L^x}{\delta \overline{T_L}} = \dfrac{c_p + L_v \overline{q}_L \overline{\alpha}_L}{c_p + L_v q_L^x \alpha_L^x} = $ The scaling factor of land temperature at percentile x
#
# The idea is that you would try all the same stuff as we tried before to come up with some good correlations
#
# ##### Most important - continuing to chug along on doing the grid cell specific analysis
# - The hope from this is that we could catigorize regions into having predictable vs not so predictable responses via gamma parameter
#
#
#  </details>

# %% [markdown]
# ---
# ## Grid Cell Specific Calculations
#
# #### Some methods things I want to run past you quickly...
#
# - part of the calculation for gamma
# has us figuring out what percentile of MSE a value of MSE corresponds to
# - Intead of doing this with scoreOfPercentile - scipy function (very computationally ineffecient) I'm preconstructing a PDF of MSE values and interpolating the percentile from the pdf
# - Some initial testing of the strategy usually gets the percentile to within 0.5 of a percentile at 500 bin pdfs when compared to the scipy function
#
# Additionally...
# - using a very similar approach to estimate where a certian percentile lies
#
# All of this has had a decent effect on speeding up the process but might be slightly less exact than previous efforts - but results still look cohesive and not crazy noisy so I think its alright?

# %% [markdown]
# #### Alright time for some graphs!
#
# ### overview - real vs predicted dT_x
#
# This is 95th percentile temps (real should say simulated)
#
# ![download.png](attachment:c793d9b9-e43f-45a9-a53b-789c37bb8924.png)
#
# ### Comparing the calculated gamma term to $\delta T_L^x / \delta T_O$ - which is just the rearrangment of the gamma term
#
# ![download.png](attachment:7dcbeb6d-c2f0-4c18-bfcd-be83d4fa0ce3.png)
#
# **This is a plot of correlations between $\lambda$ and  $dT^{x}_{L}$**
#
# ![download.png](attachment:264f1c19-9e45-4ba3-8f32-1bc5bfc53e90.png)
#
# Generallu we see positive correlations which is good and what we'd expect - interestingly we also see slightly negative correlations
#
# - ie that the change in high percentile temperatures in a given grid box decreases as lambda increases???? - doesn't fully make sense
#
#
# **This graph is the correlations between  $\lambda$ and  $dT^{x}_{L}$ for the 95th percentile**
#
# ![download.png](attachment:d63840a1-5feb-4db4-b715-6b3ae76f8e66.png)
#
# Cross hatching indicates that these areas are significantly correlated to p<0.05 for a given grid box
#
# Looking into some of these subsetted regions is interesting...
#
# **Looking see  - Plotting all gamma values against the change in 95th percentile temperature**
#
# <div>
# <img src="attachment:73a903cd-88a1-4938-b95f-b65369c03bf4.png" width="200"/>
# </div>
# <div>
# <img src="attachment:4efd2aa9-b546-4993-90fe-c429e8c9e3c3.png" width="200"/>
# </div>
# <div>
# <img src="attachment:fd1f5bb7-3aaf-48e3-9446-3012fdfb75b0.png" width="200"/>
# </div>

# %% [markdown]
# ##### But actually ^ this isn't really what we want to be doing
# - Up here we are comparing all models and all grid boxes in a region
# - Theres no reason a region should all move along a line - but an individual grid box should in theory...
# - So you'd want to visualize all the regressions for each grid box in a region
#
# This is really what the cross hatching is saying already...
# <div>
# <img src="attachment:237946e4-269d-46f3-b1cb-199fc237f66b.png" width="400"/>
# </div>
# <div>
# <img src="attachment:c18d4da2-611e-4d41-9df8-664916e05081.png" width="400"/>
# </div>
# <div>
# <img src="attachment:7e0ba91f-bbea-441c-b442-b6917c6eeed9.png" width="400"/>
# </div>
#
#
# Encouraging that these are all going the same way - and along a curve that we'd expect
#
# This region two is an interesting case...
#
# $\delta T_L^x = \gamma ^{T_O} \delta T_O$
#
#
# $\gamma ^{T_O} = \dfrac{(c_p + L_v \alpha_O q_O)}{(c_p + L_v \alpha _L q_L^x)}$
#
# How would this turn into a negative relationship? - ie what went?

# %% [markdown]
# ### Along a similar vein to with the latitude by latitude calculations we can look at this $\dfrac{\delta T_L^x}{\delta T_O}$ vs $\gamma ^{T_O}$ - for 95th percentile
#
# ![download.png](attachment:29ad7c27-407a-4f2a-bc4c-0cfc67ab1c04.png)
#
#
# <div>
# <img src="attachment:dca1f578-9303-4484-b64a-5a305f8b0caf.png" width="400"/>
# </div>
# <div>
# <img src="attachment:d8154d0e-cec0-4bdf-89f1-393dbd3f6866.png" width="400"/>
# </div>

# %% [markdown]
# ### Things to note:
# - All model results are calculated on their native grids and then interpolated to the grid used in GFDL-CM4 - which I think is acceptable
# - This does leave some funny business on the coastlines where some models are defined and some are not. If I redo these calculations I want to do some thinking about how to make this better across models - bc you end up with smaller sample sizes on coastline
# - In the calculation of gamma - Alpha wouldnt have as much emergent constraint-yness - so we've talked about ways to do this without relying on future changes
# - However priliminary exploration suggests that fiddeling resulting from different calculations of alpha wouldn't majorly change the results
# - But for now this is done with the more 'robust' alpha calculation from the fixed RH version of the theory

# %% [markdown]
# ### qualitative?
# - In North Africa - gamma is overestimated leading to predicting more extreme changes than are real...
# - In Central SA - gamma is underestimated leading to underpredicting extreme temp changes
#
# NA - Dry
#
# SA - Wet?

# %% [markdown]
# ---
# ### Things for next time
#
# - Prep for meeting with Graeme Tuesday
# - Generally just check over calculations and make sure everything checks out, I think everything is fine but you never know
# - See what happens if you leave out some of the weirder models
# - residuals by area might be interesting...
# - figure out some better ways to visualize trends across percentiles ^ most of this was at the 95th percentile - but we've got data for 26 levels so might as well look at them
# - Prelim look doesn't look that crazy but worth exploring

# %% [markdown]
# ## File Pathing for CMIP6 4xCO2 and piControl simulations
# #### 10/12/2024
# ---

# %% [markdown]
# ### Steps:
# 1. Using CEDA we grab a list of all models in the CMIP6 archive (72 Models)
# 2. Using the ESGF python search api we search for models that include any of the variables of interest
#    - tas, huss, hurs, ps (for my use case)
# 3. We export the search results of this out to individual csv files that we later composite back together
# 4. From the composite we find the models that have deal breaker variables included
# 5. Have a function that is used to retrieve any dataset
#
# ---

# %% [markdown]
# #### Librarys

# %%
import numpy as np
import xarray as xr
import pandas as pd
import os
from pyesgf.search import SearchConnection
os.environ["ESGF_PYCLIENT_NO_FACETS_STAR_WARNING"] = "on"

def extract_8_chars(string):
    start_index = string.find('_r') 
    end_index = string.find('_', start_index+1)
    return string[start_index+1:end_index]

def extract_SimNums(string):
    try:
        start_index = string.find('_r')
        end_index = string.find('i', start_index)
        r = int(string[start_index + 2:end_index])

        start_index = string.find('i', end_index)
        end_index = string.find('p', start_index)
        i = int(string[start_index + 1:end_index])

        start_index = string.find('p', end_index)
        end_index = string.find('f', start_index)
        p = int(string[start_index + 1:end_index])

        start_index = string.find('f', end_index)
        end_index = string.find('_', start_index)
        f = int(string[start_index + 1:end_index])
        
        return r, i, p, f
    except Exception as e:
        # Provide feedback for debugging
        print(f"Error processing string '{string}': {e}")
        return None, None, None, None
   
def getPeriod(filename):
    if 'abrupt-4xCO2' in filename: return 'abrupt-4xCO2'
    elif 'piControl' in filename: return 'piControl'
def whichVar(filename):
    if 'tas' in filename: return 'tas'
    elif 'huss' in filename: return 'huss'
    elif 'hurs' in filename: return 'hurs'
    elif 'ps' in filename: return 'ps'
        
conn = SearchConnection('https://esgf.ceda.ac.uk/esg-search', distrib=True) #UK one
# conn = SearchConnection('https://esgf-node.llnl.gov/esg-search', distrib=True) #German one
# conn = SearchConnection('https://esgf-data.dkrz.de/esg-search', distrib=True)  #US one

# %%
extract_8_chars('ps_Amon_CMCC-ESM2_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc')
# Out:
# 'r1i1p1f1'

# %% [markdown]
# #### 1: Grabbing the list of models in CMIP6 from CEDA archive

# %%
Agencies = os.listdir(f'/badc/cmip6/data/CMIP6/CMIP/')
Models = [os.listdir(f'/badc/cmip6/data/CMIP6/CMIP/{Agency}') for Agency in Agencies]
models = []
for sublist in Models:
    models.extend(sublist)

# %% [markdown]
# #### 2: Searching with pyesgf search (time consuming)

# %%
def calc(model): 
    if os.path.isfile(f'CO2_4x_url_{model}.csv'):
        print('skip')
        return None
    else:
        print(model) # for monitoring progress of parallel execution
        query = conn.new_context(project="CMIP6",     
                                 experiment_id='abrupt-4xCO2,piControl',
                                 source_id = model,
                                 frequency = 'day', 
                                 # member_id="r1i1p1f1",
                                 variable_id = "tas,huss,ps,hurs")
        results = query.search()
        
        files = []
        for i in range(len(results)):
            try:
                hit = results[i].file_context().search()
            except:
                hit = results[i].file_context().search()
            files += list(map(lambda f: {'model': model,
                                         'filename': f.filename, 
                                         'download_url': f.download_url, 
                                         'opendap_url': f.opendap_url}, hit))
        
        df = pd.DataFrame.from_dict(files)
        if len(df) == 0: return None
        df = df.dropna() # some opendap_urls are not found - so get rid of those
        df[['r', 'i', 'p', 'f']] = pd.DataFrame(
            df['filename'].apply(extract_SimNums).tolist(),
            index=df.index
        )
                
        df['Varient'] = df.filename.apply(extract_8_chars)
        df['period'] = df.filename.apply(getPeriod)
        df['Var'] = df.filename.apply(whichVar)
        df['timeStep'] = 'day'
        df['openDapWorking'] = False
        
        # discreteFiles = df.filename.unique()
        
        for i, dFile in enumerate(discreteFiles):
            for openDap in df[df.filename == dFile].opendap_url:
                try: 
                    xr.open_dataset(openDap)
                    df['openDapWorking'][df.opendap_url == openDap] = True
                    break
                except:
                    pass
        df.to_csv(f'CO2_4x_url_{model}.csv')   # Saves to CSV
        return None
## So turns out not every opendap works - Im going to blow my brains out
## So we need to not drop duplicates and then also deal with brutforcing through figuring out which ones work.

def parallel_execution(func, inputs, processes=None):
    from multiprocessing import Pool, cpu_count

    # Set the number of processes to use (default: number of CPU cores)
    if processes is None:
        processes = cpu_count()

    # Create a pool of worker processes
    with Pool(processes=processes) as pool:
        # Map the function to inputs and distribute across processors
        results = pool.map(func, inputs)

    return results

# processes = 8 works best for me - you won't overload RAM but their server can only process so many search requests
results = parallel_execution(calc, models, processes=8)
# Out:
# skipBCC-CSM2-MRskipCAS-ESM2-0skipskipskipE3SM-1-1
#
#
#
#
# skip
#
#
# skip
# skipskipskipskip
#
#
#
#
# skipskipskip
# skipCanESM5-CanOE
#
# skipskip
#
# EC-Earth3P-VHR
#
# skip
# skipskip
#
#
# skipskipskip
#
# skip
# skip
# skip
#
# skipskip
# skip
# skip
# UKESM1-1-LL
# skip
# skip
#
# GISS-E2-1-G-CCskip
#
# skip
# GISS-E2-1-G
# GISS-E2-1-H
# skipskip
#
# skipskip
#
# skip
# skipE3SM-1-1-ECAskipskip
#
#
#
# skipskipskip
#
#
# NorCPM1NorESM1-Fskip
#
#
# skip
# GFDL-AM4
# skip
# skip
# NESM3
# BCC-ESM1
# skip
# CIESM
# skip
# skip
# skip
# skip
# MCM-UA-1-0
# CAMS-CSM1-0

# %% [markdown]
# #### 3: Composite Models back together and note if any didn't save properly

# %%
df = pd.DataFrame()
notIn = []
for model in models:
    try:
        df_add = pd.read_csv(f'CO2_4x_url_{model}.csv', index_col=0)
        df = pd.concat([df, df_add], ignore_index=True)
    except:
        print(f'{model} not included')
        notIn.append(model)

df.to_csv(f'CO2_4x_url_all.csv', index=None)
#6JGFX2W7
# Out:
# BCC-CSM2-MR not included
# BCC-ESM1 not included
# CAMS-CSM1-0 not included
# CAS-ESM2-0 not included
# CanESM5-CanOE not included
# E3SM-1-1 not included
# E3SM-1-1-ECA not included
# EC-Earth3P-VHR not included
# UKESM1-1-LL not included
# GISS-E2-1-G not included
# GISS-E2-1-G-CC not included
# GISS-E2-1-H not included
# NorCPM1 not included
# NorESM1-F not included
# GFDL-AM4 not included
# NESM3 not included
# CIESM not included
# MCM-UA-1-0 not included

# %% [markdown]
# #### 4: Setting variables that must be present to be a usable model - and determining list of usable models

# %%
# List of all requested vars and all of those that must be included for a model to be usable
allVars = ['tas', 'huss', 'hurs', 'ps']
insistVars = ['tas', 'huss', 'hurs']

df = pd.read_csv('CO2_4x_url_all.csv', index_col=None)
df = df[df.openDapWorking]


### Some Stats for what you've fetched
print(f'we tried to find information for {len(models)}')
print(f'We are unable to find any files for {len(set(models) - set(df.model.unique())- set(notIn))} models')
print(f'We have yet to process {len(notIn)}')

# some pandas magic to find models where all the insisted upon vars are included
groups = df.groupby(['model',  'Var', 'period'], as_index=False).Var.value_counts()

if len(insistVars) == 0:
    tasHuss = groups.groupby(['model'], as_index = False).model.value_counts()
else:
    tasHuss = groups[~groups['Var'].isin(list(set(allVars) - set(insistVars)))].groupby(['model'], as_index = False).model.value_counts()

goodModels = tasHuss[tasHuss['count'] == len(insistVars)*2].reset_index(drop=True).model    # the 2 in here will mess up if you have a dif number of periods

print(f'we can find {len(goodModels)} models that include {insistVars} for both 4xco2 and PI')

df = df[df['model'].isin(goodModels)]


## So well have to find the pressure feilds from alot of these - either in Amon or day?


shared_combinations = {}

for (period, model), group in df.groupby(['period', 'model']):
    combinations_per_variable = (
        group.groupby('Var')[['r', 'f', 'p', 'i']]
        .apply(lambda var_group: set(tuple(x) for x in var_group.to_numpy()))
        .tolist()
    )
    if combinations_per_variable:
        shared_combinations_for_group = set.intersection(*combinations_per_variable)
    else:
        shared_combinations_for_group = set()
    shared_combinations[(period, model)] = shared_combinations_for_group

filtered_dfs = []

for (period, model), combinations in shared_combinations.items():
    if combinations:  
        first_combination = next(iter(combinations))  
        
        filtered_df = df[
            (df['period'] == period) & 
            (df['model'] == model) & 
            (df[['r', 'f', 'p', 'i']].apply(tuple, axis=1) == first_combination)
        ]
        filtered_dfs.append(filtered_df)
        
df = pd.concat(filtered_dfs, ignore_index=True)
df = df[df['Var'] != 'ps']    # we are going to only use monthly ps to keep things consistant
for model in df.model.unique():
    checkEmpty = False
    for period in df.period.unique():
        if len(df[(df['model'] == model) & (df['period'] == period)]) == 0: checkEmpty = True

    if checkEmpty:
        df = df[~(df['model'] == model)]
# ## This step sees if there is available ps if there is in both then you leave it if theres one or the other you take out both, if theres none you leave it
# monModels = []
# for model in df.model.unique():
#     bools = []    
#     for period in df.period.unique():
#         d = df[(df['model'] == model) & (df['period'] == period)].Var.unique() 
#         bools.append('ps' in set(d))
        
#     if (bools[0] ^ bools[1]):
#         monModels.append(model)
#         df = df[~((df['model'] == model) & (df['Var'] == 'ps')) ]
#     if not(bools[0] or bools[1]):
#         monModels.append(model)
# df =df.reset_index(drop=True)

# dfmon = pd.read_csv('CO2_4x_url_all_psMon.csv')

# dfmon = dfmon.dropna() 
# dfmon[['r', 'i', 'p', 'f']] = pd.DataFrame(
#     dfmon['filename'].apply(extract_SimNums).tolist(),
#     index=dfmon.index
# )

# dfmon['Varient'] = dfmon.filename.apply(extract_8_chars)
# dfmon['period'] = dfmon.filename.apply(getPeriod)
# dfmon['Var'] = dfmon.filename.apply(whichVar)
# dfmon['timeStep'] = 'mon'

# for model in monModels:
#     for period in df.period.unique():
#         Varient = df[(df['model'] == model) & (df['period'] == period)].Varient.unique()[0]
#         dfadd = dfmon[((dfmon['model'] == model) & (dfmon['period'] == period)) & (dfmon['Varient'] == Varient)]
#         df = pd.concat([df, dfadd], ignore_index=True)


df[['start', 'stop']] = df['filename'].apply(lambda x: pd.Series(extractDates(x)))

df.to_csv('CO2_4x_url_usable.csv', index = False)
# Out:
# we tried to find information for 72
# We are unable to find any files for 0 models
# We have yet to process 40
# we can find 32 models that include ['tas', 'huss', 'hurs'] for both 4xco2 and PI

# %%
def extractDates(string):
    ncFind = string.find('.nc') 
    ncBack = string.rfind('-', 0, ncFind)
    dback = (ncFind-ncBack)-1
    stop = string[ncBack+1:ncFind]
    start = string[ncBack-dback:ncBack]
    try:
        return extractYear(start), extractYear(stop)
    except:
        print(string)
def extractYear(Date):
    return Date[:4]
extractDates('ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc')
# Out:
# ('0501', '0600')

# %% [markdown]
# #### 5: Making a function to grab any set of opendap_url's

# %%
### from df we are going to find the model, period, varient combo that is needed to complete the ps variables
df = pd.read_csv('CO2_4x_url_usable.csv')

for model in df.model.unique():
    bools = []
    print(model)
    for period in df.period.unique():
        print(set(df[(df['model'] == model) & (df['period'] == period)].Varient.unique()))

len(df.model.unique())
# Out:
# ACCESS-CM2
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# ACCESS-ESM1-5
# {'r2i1p1f1'}
# {'r1i1p1f1'}
# CESM2
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# CESM2-FV2
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# CESM2-WACCM
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# CESM2-WACCM-FV2
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# CMCC-CM2-SR5
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# CMCC-ESM2
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# CNRM-CM6-1
# {'r1i1p1f2'}
# {'r1i1p1f2'}
# CNRM-CM6-1-HR
# {'r1i1p1f2'}
# {'r1i1p1f2'}
# CNRM-ESM2-1
# {'r1i1p1f2'}
# {'r1i1p1f2'}
# CanESM5
# {'r1i1p2f1'}
# {'r1i1p2f1'}
# EC-Earth3
# {'r3i1p1f1'}
# {'r1i1p1f1'}
# EC-Earth3-CC
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# EC-Earth3-Veg
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# EC-Earth3-Veg-LR
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# GFDL-CM4
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# HadGEM3-GC31-LL
# {'r1i1p1f3'}
# {'r1i1p1f1'}
# HadGEM3-GC31-MM
# {'r1i1p1f3'}
# {'r1i1p1f1'}
# IITM-ESM
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# IPSL-CM5A2-INCA
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# KIOST-ESM
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# MIROC-ES2H
# {'r3i1p4f2'}
# {'r1i1p4f2'}
# MIROC-ES2L
# {'r1i1p1f2'}
# {'r1i1p1f2'}
# MIROC6
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# MRI-ESM2-0
# {'r5i1p1f1'}
# {'r1i1p1f1'}
# NorESM2-LM
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# NorESM2-MM
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# SAM0-UNICON
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# TaiESM1
# {'r1i1p1f1'}
# {'r1i1p1f1'}
# UKESM1-0-LL
# {'r1i1p1f2'}
# {'r1i1p1f2'}
# 31

# %% [markdown]
# ---
# ### Thats the daily vars taken care of
# - however we need to do monthly for ps on the models where we don't have ps vars
#
# **Steps for this:**
# 1. Identify which models are close but don't include just ps
# 2. Use same search as above to find monthly ps
# 3. Save this to csv files
# 4. Incorperate this into the url_usable csv file somehow
# ---
#
# #### 1: Identifying models which would be usable apart from daily ps

# %%
# Out:
# 18

# %% [markdown]
# #### 2: Using search to look for monthly pressure for these models: (time consuming)

# %%
def calc(model): 
    print(model) # for monitoring progress of parallel execution
    query = conn.new_context(project="CMIP6",     
                             experiment_id='abrupt-4xCO2,piControl',
                             source_id = model,
                             frequency = 'mon', 
                             # member_id="r1i1p1f1",
                             variable_id = "ps")
    results = query.search()
        
    files = []
    for i in range(len(results)):
        try:
            hit = results[i].file_context().search()
        except:
            hit = results[i].file_context().search()
        files += list(map(lambda f: {'model': model,
                                     'filename': f.filename, 
                                     'download_url': f.download_url, 
                                     'opendap_url': f.opendap_url}, hit))
    
    df = pd.DataFrame.from_dict(files)
    if len(df) == 0: 
        print(model, ': no results ')
        return None
    df = df.dropna() # some opendap_urls are not found - so get rid of those
    df[['r', 'i', 'p', 'f']] = pd.DataFrame(
        df['filename'].apply(extract_SimNums).tolist(),
        index=df.index
    )
            
    df['Varient'] = df.filename.apply(extract_8_chars)
    df['period'] = df.filename.apply(getPeriod)
    df['Var'] = df.filename.apply(whichVar)
    df['timeStep'] = 'mon'
    df['openDapWorking'] = False
    
    discreteFiles = df.filename.unique()
    
    for i, dFile in enumerate(discreteFiles):
        for openDap in df[df.filename == dFile].opendap_url:
            try: 
                xr.open_dataset(openDap)
                df['openDapWorking'][df.opendap_url == openDap] = True
                break
            except:
                pass
    df.to_csv(f'CO2_4x_url_{model}_psMon.csv')   # Saves to CSV
    return None

def parallel_execution(func, inputs, processes=None):
    from multiprocessing import Pool, cpu_count

    # Set the number of processes to use (default: number of CPU cores)
    if processes is None:
        processes = cpu_count()

    # Create a pool of worker processes
    with Pool(processes=processes) as pool:
        # Map the function to inputs and distribute across processors
        results = pool.map(func, inputs)

    return results

df = pd.read_csv('CO2_4x_url_usable.csv')

models = df.model.unique()
# processes = 8 works best for me - you won't overload RAM but their server can only process so many search requests
results = parallel_execution(calc, models, processes=8)
# Out:
# ACCESS-ESM1-5ACCESS-CM2CESM2-WACCMCESM2-WACCM-FV2
# CMCC-CM2-SR5CESM2-FV2CESM2
# CMCC-ESM2
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:172: SerializationWarning: Ambiguous reference date string: 950-01-01. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0950-01-01). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:992: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /opt/jaspy/lib/python3.11/site-packages/xarray/core/indexing.py:526: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:172: SerializationWarning: Ambiguous reference date string: 950-01-01. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0950-01-01). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:992: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /opt/jaspy/lib/python3.11/site-packages/xarray/core/indexing.py:526: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# CNRM-CM6-1
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# CNRM-CM6-1-HR
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# CNRM-ESM2-1
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:172: SerializationWarning: Ambiguous reference date string: 101-01-01. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0101-01-01). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:992: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /opt/jaspy/lib/python3.11/site-packages/xarray/core/indexing.py:526: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:172: SerializationWarning: Ambiguous reference date string: 101-01-01. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0101-01-01). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:992: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /opt/jaspy/lib/python3.11/site-packages/xarray/core/indexing.py:526: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:172: SerializationWarning: Ambiguous reference date string: 101-01-01. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0101-01-01). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:992: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /opt/jaspy/lib/python3.11/site-packages/xarray/core/indexing.py:526: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:172: SerializationWarning: Ambiguous reference date string: 101-01-01. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0101-01-01). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:992: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /opt/jaspy/lib/python3.11/site-packages/xarray/core/indexing.py:526: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:172: SerializationWarning: Ambiguous reference date string: 101-01-01. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0101-01-01). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:992: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /opt/jaspy/lib/python3.11/site-packages/xarray/core/indexing.py:526: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:172: SerializationWarning: Ambiguous reference date string: 101-01-01. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0101-01-01). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# /opt/jaspy/lib/python3.11/site-packages/xarray/coding/times.py:992: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /opt/jaspy/lib/python3.11/site-packages/xarray/core/indexing.py:526: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# CanESM5
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /opt/jaspy/lib/python3.11/site-packages/xarray/conventions.py:286: SerializationWarning: variable 'ps' has multiple fill values {1e+20, 1e+20} defined, decoding all values to NaN.
#   var = coder.decode(var, name=name)
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# ...
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['openDapWorking'][df.opendap_url == openDap] = True
# /tmp/ipykernel_561/2449440592.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['openDapWorking'][df.opendap_url == openDap] = True

# %%
len(models)
# Out:
# 31

# %% [markdown]
# #### 3: Compositing this all back together

# %%
df = pd.DataFrame()
notIn = []
for model in models:
    try:
        df_add = pd.read_csv(f'CO2_4x_url_{model}_psMon.csv', index_col=0)
        df = pd.concat([df, df_add], ignore_index=True)
    except:
        print(f'{model} not included')
        notIn.append(model)
df['timeStep'] = 'mon'


df[['start', 'stop']] = df['filename'].apply(lambda x: pd.Series(extractDates(x)))
df.to_csv(f'CO2_4x_url_all_psMon.csv', index=None)
# --------------------------------------------------------
dfday = pd.read_csv('CO2_4x_url_usable.csv')
dfmon = pd.read_csv('CO2_4x_url_all_psMon.csv')
dfday = dfday[dfday.openDapWorking]
dfmon = dfmon[dfmon.openDapWorking]
dfs = []
i = 0
for model in df.model.unique():
    for period in df.period.unique():
        Varient = dfday[(dfday['model'] == model) & (dfday['period'] == period)].Varient.unique()[0]
        monsub = dfmon[((dfmon['model'] == model) & (dfmon['period'] == period)) & (dfmon['Varient'] == Varient)]
        if len(monsub) == 0: print(model, period)
        dfs.append(monsub)

dfmon = pd.concat(dfs, ignore_index=True)
dfAll = pd.concat([dfday, dfmon ], ignore_index=True)
dfAll.to_csv('CO2_4x_url_usable_wMon.csv')
# Out:
# AWI-CM-1-1-MR not included
# AWI-ESM-1-1-LR not included
# BCC-CSM2-MR not included
# BCC-ESM1 not included
# CAMS-CSM1-0 not included
# CAS-ESM2-0 not included
# FGOALS-f3-L not included
# FGOALS-g3 not included
# CanESM5-CanOE not included
# CMCC-CM2-HR4 not included
# E3SM-1-0 not included
# E3SM-1-1 not included
# E3SM-1-1-ECA not included
# E3SM-2-0 not included
# EC-Earth3-AerChem not included
# EC-Earth3-LR not included
# EC-Earth3P-VHR not included
# FIO-ESM-2-0 not included
# MPI-ESM-1-2-HAM not included
# INM-CM4-8 not included
# INM-CM5-0 not included
# IPSL-CM6A-LR not included
# IPSL-CM6A-LR-INCA not included
# UKESM1-1-LL not included
# ICON-ESM-LR not included
# MPI-ESM1-2-HR not included
# MPI-ESM1-2-LR not included
# GISS-E2-1-G not included
# GISS-E2-1-G-CC not included
# GISS-E2-1-H not included
# GISS-E2-2-G not included
# GISS-E2-2-H not included
# NorCPM1 not included
# NorESM1-F not included
# KACE-1-0-G not included
# GFDL-AM4 not included
# GFDL-ESM4 not included
# NESM3 not included
# CIESM not included
# MCM-UA-1-0 not included
# ps_Amon_TaiESM1_abrupt-4xCO2_r1i1p1f1_gn_000101-015012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Amon_TaiESM1_abrupt-4xCO2_r1i1p1f1_gn_000101-015012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Emon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_Emon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_Emon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_Emon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_Emon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Amon_TaiESM1_abrupt-4xCO2_r1i1p1f1_gn_000101-015012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Emon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_Emon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_Emon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_Emon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_Emon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Amon_TaiESM1_abrupt-4xCO2_r1i1p1f1_gn_000101-015012.nc
# ps_Emon_TaiESM1_abrupt-4xCO2_r1i1p1f1_gn_000101-015012.nc
# ps_AERmon_TaiESM1_abrupt-4xCO2_r1i1p1f1_gn_000101-015012.nc
# ps_Amon_TaiESM1_abrupt-4xCO2_r1i1p1f1_gn_000101-015012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_AERmon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_020101-030012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_030101-040012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_040101-050012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_050101-060012.nc
# ps_Amon_TaiESM1_piControl_r1i1p1f1_gn_060101-070012.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_185001-185912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_186001-186912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_187001-187912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_188001-188912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_189001-189912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_190001-190912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_191001-191912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_192001-192912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_193001-193912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_194001-194912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_195001-195912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_196001-196912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_197001-197912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_198001-198912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_199001-199912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_200001-200912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_201001-201412.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_192601-193512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_193601-194512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_194601-195012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_195101-196012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_196101-197012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_197101-198012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_198101-199012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_199101-200012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_200101-201012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_201101-202012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_202101-203012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_203101-204012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_204101-205012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_205101-206012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_206101-207012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_207101-208012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_208101-209012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_209101-210012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_210101-211012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_211101-212012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_212101-212512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_192601-193512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_193601-194512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_194601-195012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_195101-196012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_196101-197012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_197101-198012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_198101-199012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_199101-200012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_200101-201012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_201101-202012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_202101-203012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_203101-204012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_204101-205012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_205101-206012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_206101-207012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_207101-208012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_208101-209012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_209101-210012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_210101-211012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_211101-212012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_212101-212512.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_185001-185912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_186001-186912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_187001-187912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_188001-188912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_189001-189912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_190001-190912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_191001-191912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_192001-192912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_193001-193912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_194001-194912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_195001-195912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_196001-196912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_197001-197912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_198001-198912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_199001-199912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_200001-200912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_201001-201412.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_192601-193512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_193601-194512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_194601-195012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_195101-196012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_196101-197012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_197101-198012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_198101-199012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_199101-200012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_200101-201012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_201101-202012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_202101-203012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_203101-204012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_204101-205012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_205101-206012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_206101-207012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_207101-208012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_208101-209012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_209101-210012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_210101-211012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_211101-212012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_212101-212512.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_185001-185912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_186001-186912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_187001-187912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_188001-188912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_189001-189912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_190001-190912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_191001-191912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_192001-192912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_193001-193912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_194001-194912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_195001-195912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_196001-196912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_197001-197912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_198001-198912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_199001-199912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_200001-200912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_201001-201412.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_192601-193512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_193601-194512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_194601-195012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_195101-196012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_196101-197012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_197101-198012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_198101-199012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_199101-200012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_200101-201012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_201101-202012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_202101-203012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_203101-204012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_204101-205012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_205101-206012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_206101-207012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_207101-208012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_208101-209012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_209101-210012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_210101-211012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_211101-212012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_212101-212512.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_185001-185912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_186001-186912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_187001-187912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_188001-188912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_189001-189912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_190001-190912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_191001-191912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_192001-192912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_193001-193912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_194001-194912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_195001-195912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_196001-196912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_197001-197912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_198001-198912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_199001-199912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_200001-200912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_201001-201412.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_199001-199912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_200001-200912.nc
# ps_Amon_IITM-ESM_abrupt-4xCO2_r1i1p1f1_gn_201001-201412.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_192601-193512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_193601-194512.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_194601-195012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_195101-196012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_196101-197012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_197101-198012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_198101-199012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_199101-200012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_200101-201012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_201101-202012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_202101-203012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_203101-204012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_204101-205012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_205101-206012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_206101-207012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_207101-208012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_208101-209012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_209101-210012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_210101-211012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_211101-212012.nc
# ps_Amon_IITM-ESM_piControl_r1i1p1f1_gn_212101-212512.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p2f1_gn_185001-200012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_520101-540012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_540101-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_580101-600012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_600101-620012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_555001-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_580101-600012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_555001-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_580101-600012.nc
# ps_AERmon_CanESM5_abrupt-4xCO2_r1i1p2f1_gn_185001-200012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p2f1_gn_185001-200012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_AERmon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_520101-540012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_540101-560012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_560101-580012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_580101-600012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_600101-620012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_520101-540012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_540101-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_580101-600012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_600101-620012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p2f1_gn_185001-200012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_AERmon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p2f1_gn_185001-200012.nc
# ps_AERmon_CanESM5_abrupt-4xCO2_r1i1p2f1_gn_185001-200012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_520101-540012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_540101-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_580101-600012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_600101-620012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_520101-540012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_540101-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_580101-600012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_520101-540012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_540101-560012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_560101-580012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_580101-600012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_600101-620012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_520101-540012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_540101-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_580101-600012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_600101-620012.nc
# ps_AERmon_CanESM5_abrupt-4xCO2_r1i1p2f1_gn_185001-200012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_555001-560012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_560101-580012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_580101-600012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_600101-620012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_620101-640012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_640101-660012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_520101-540012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_540101-560012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_560101-580012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_580101-600012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_600101-620012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_555001-560012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_560101-580012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_580101-600012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_600101-620012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_620101-640012.nc
# ps_AERmon_CanESM5_piControl_r1i1p2f1_gn_640101-660012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_555001-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_580101-600012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_600101-620012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_620101-640012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_640101-660012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_555001-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_580101-600012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_600101-620012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_620101-640012.nc
# ps_Amon_CanESM5_piControl_r1i1p2f1_gn_640101-660012.nc
# ps_AERmon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_520101-540012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_540101-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_580101-600012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_600101-620012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_600101-620012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_520101-540012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_540101-560012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_560101-580012.nc
# ps_Amon_CanESM5_piControl_r1i1p1f1_gn_580101-600012.nc
# ps_AERmon_CanESM5_piControl_r1i1p1f1_gn_600101-620012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_Amon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_AERmon_CanESM5_abrupt-4xCO2_r1i1p1f1_gn_185001-200012.nc
# ps_Amon_CMCC-CM2-SR5_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_210001-234912.nc
# ps_Amon_CMCC-CM2-SR5_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_210001-234912.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_210001-234912.nc
# ps_Amon_CMCC-CM2-SR5_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_210001-234912.nc
# ps_Amon_CMCC-CM2-SR5_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_210001-234912.nc
# ps_Amon_CMCC-CM2-SR5_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-CM2-SR5_piControl_r1i1p1f1_gn_210001-234912.nc
# ps_Amon_CMCC-CM2-SR5_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc
# ps_Amon_CMCC-ESM2_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc
# ps_Amon_CMCC-ESM2_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-ESM2_piControl_r1i1p1f1_gn_210001-234912.nc
# ps_Amon_CMCC-ESM2_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc
# ps_Amon_CMCC-ESM2_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-ESM2_piControl_r1i1p1f1_gn_210001-234912.nc
# ps_Amon_CMCC-ESM2_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-ESM2_piControl_r1i1p1f1_gn_210001-234912.nc
# ps_Amon_CMCC-ESM2_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-ESM2_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc
# ps_Amon_CMCC-ESM2_piControl_r1i1p1f1_gn_185001-209912.nc
# ps_Amon_CMCC-ESM2_piControl_r1i1p1f1_gn_210001-234912.nc
# ps_Amon_CMCC-ESM2_abrupt-4xCO2_r1i1p1f1_gn_185001-201412.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r2i1p1f2_gr_185003-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r3i1p1f2_gr_185005-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r4i1p1f2_gr_185007-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r5i1p1f2_gr_185009-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r6i1p1f2_gr_185011-185912.nc
# ps_Amon_CNRM-CM6-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_AERmon_CNRM-CM6-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-CM6-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r4i1p1f2_gr_185007-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r2i1p1f2_gr_185003-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r3i1p1f2_gr_185005-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r5i1p1f2_gr_185009-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r6i1p1f2_gr_185011-185912.nc
# ps_AERmon_CNRM-CM6-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-CM6-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r2i1p1f2_gr_185003-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r4i1p1f2_gr_185007-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r5i1p1f2_gr_185009-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r3i1p1f2_gr_185005-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r6i1p1f2_gr_185011-185912.nc
# ps_Amon_CNRM-CM6-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r2i1p1f2_gr_185003-185912.nc
# ps_Amon_CNRM-CM6-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_AERmon_CNRM-CM6-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r3i1p1f2_gr_185005-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r4i1p1f2_gr_185007-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r5i1p1f2_gr_185009-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r6i1p1f2_gr_185011-185912.nc
# ps_Amon_CNRM-CM6-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_AERmon_CNRM-CM6-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-CM6-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-CM6-1-HR_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-CM6-1-HR_piControl_r1i1p1f2_gr_185001-214912.nc
# ps_Amon_CNRM-CM6-1-HR_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-CM6-1-HR_piControl_r1i1p1f2_gr_185001-214912.nc
# ps_Amon_CNRM-CM6-1-HR_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-CM6-1-HR_piControl_r1i1p1f2_gr_185001-214912.nc
# ps_Amon_CNRM-CM6-1-HR_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-CM6-1-HR_piControl_r1i1p1f2_gr_185001-214912.nc
# ps_Amon_CNRM-CM6-1-HR_piControl_r1i1p1f2_gr_185001-214912.nc
# ps_Amon_CNRM-CM6-1-HR_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r2i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r3i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r3i1p1f2_gr_185001-199912.nc
# ps_AERmon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_185001-209912.nc
# ps_AERmon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_210001-210512.nc
# ps_Amon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r2i1p1f2_gr_185001-199912.nc
# ps_AERmon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_185001-209912.nc
# ps_AERmon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_210001-210512.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r3i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r2i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r2i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r3i1p1f2_gr_185001-199912.nc
# ps_AERmon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_185001-209912.nc
# ps_AERmon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_210001-210512.nc
# ps_Amon_CNRM-ESM2-1_abrupt-4xCO2_r1i1p1f2_gr_185001-199912.nc
# ps_Amon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_185001-234912.nc
# ps_AERmon_CNRM-ESM2-1_piControl_r1i1p1f2_gr_185001-209912.nc
# ps_Amon_ACCESS-ESM1-5_abrupt-4xCO2_r1i1p1f1_gn_010101-025012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_060101-100012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_060101-100012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_100101-110012.nc
# ps_Amon_ACCESS-ESM1-5_abrupt-4xCO2_r1i1p1f1_gn_010101-025012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_060101-100012.nc
# ps_Amon_ACCESS-ESM1-5_abrupt-4xCO2_r1i1p1f1_gn_010101-025012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_060101-100012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_060101-100012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_100101-110012.nc
# ps_Amon_ACCESS-ESM1-5_abrupt-4xCO2_r1i1p1f1_gn_010101-025012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_060101-100012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_100101-110012.nc
# ps_Amon_ACCESS-ESM1-5_abrupt-4xCO2_r2i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_abrupt-4xCO2_r2i1p1f1_gn_060101-110012.nc
# ps_Amon_ACCESS-ESM1-5_abrupt-4xCO2_r1i1p1f1_gn_010101-025012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_abrupt-4xCO2_r2i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_abrupt-4xCO2_r2i1p1f1_gn_060101-110012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_060101-100012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_100101-110012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_010101-060012.nc
# ps_Amon_ACCESS-ESM1-5_piControl_r1i1p1f1_gn_060101-100012.nc
# ps_Amon_ACCESS-CM2_abrupt-4xCO2_r1i1p1f1_gn_095001-109912.nc
# ps_Amon_ACCESS-CM2_piControl_r1i1p1f1_gn_095001-144912.nc
# ps_Amon_ACCESS-CM2_abrupt-4xCO2_r1i1p1f1_gn_095001-109912.nc
# ps_Amon_ACCESS-CM2_piControl_r1i1p1f1_gn_095001-144912.nc
# ps_Amon_ACCESS-CM2_abrupt-4xCO2_r1i1p1f1_gn_095001-109912.nc
# ps_Amon_ACCESS-CM2_piControl_r1i1p1f1_gn_095001-144912.nc
# ps_Amon_ACCESS-CM2_piControl_r1i1p1f1_gn_095001-144912.nc
# ps_Amon_ACCESS-CM2_abrupt-4xCO2_r1i1p1f1_gn_095001-109912.nc
# ps_Amon_ACCESS-CM2_abrupt-4xCO2_r1i1p1f1_gn_095001-109912.nc
# ps_Amon_ACCESS-CM2_piControl_r1i1p1f1_gn_095001-144912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_225901-225912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_226001-226012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_226101-226112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_226201-226212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_226301-226312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_226401-226412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_226501-226512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_226601-226612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_226701-226712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_226801-226812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_226901-226912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_227001-227012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_227101-227112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_227201-227212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_227301-227312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_227401-227412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_227501-227512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_227601-227612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_227701-227712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_227801-227812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_227901-227912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_228001-228012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_228101-228112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_228201-228212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_228301-228312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_228401-228412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_228501-228512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_228601-228612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_228701-228712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_228801-228812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_228901-228912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_229001-229012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_229101-229112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_229201-229212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_229301-229312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_229401-229412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_229501-229512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_229601-229612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_229701-229712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_229801-229812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_229901-229912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_230001-230012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_230101-230112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_230201-230212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_230301-230312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_230401-230412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_230501-230512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_230601-230612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_230701-230712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_230801-230812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_230901-230912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_231001-231012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_231101-231112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_231201-231212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_231301-231312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_231401-231412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_231501-231512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_231601-231612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_231701-231712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_231801-231812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_231901-231912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_232001-232012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_232101-232112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_232201-232212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_232301-232312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_232401-232412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_232501-232512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_232601-232612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_232701-232712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_232801-232812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_232901-232912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_233001-233012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_233101-233112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_233201-233212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_233301-233312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_233401-233412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_233501-233512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_233601-233612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_233701-233712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_233801-233812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_233901-233912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_234001-234012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_234101-234112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_234201-234212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_234301-234312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_234401-234412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_234501-234512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_234601-234612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_234701-234712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_234801-234812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_234901-234912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_235001-235012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_235101-235112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_235201-235212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_235301-235312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_235401-235412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_235501-235512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_235601-235612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_235701-235712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_235801-235812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_235901-235912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_236001-236012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_236101-236112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_236201-236212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_236301-236312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_236401-236412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_236501-236512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_236601-236612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_236701-236712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_236801-236812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_236901-236912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_237001-237012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_237101-237112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_237201-237212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_237301-237312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_237401-237412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_237501-237512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_237601-237612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_237701-237712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_237801-237812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_237901-237912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_238001-238012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_238101-238112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_238201-238212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_238301-238312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_238401-238412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_238501-238512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_238601-238612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_238701-238712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_238801-238812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_238901-238912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_239001-239012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_239101-239112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_239201-239212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_239301-239312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_239401-239412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_239501-239512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_239601-239612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_239701-239712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_239801-239812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_239901-239912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_240001-240012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_240101-240112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_240201-240212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_240301-240312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_240401-240412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_240501-240512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_240601-240612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_240701-240712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_240801-240812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_240901-240912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_241001-241012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_241101-241112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_241201-241212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_241301-241312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_241401-241412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_241501-241512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_241601-241612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_241701-241712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_241801-241812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_241901-241912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_242001-242012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_242101-242112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_242201-242212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_242301-242312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_242401-242412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_242501-242512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_242601-242612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_242701-242712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_242801-242812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_242901-242912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_243001-243012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_243101-243112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_243201-243212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_243301-243312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_243401-243412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_243501-243512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_243601-243612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_243701-243712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_243801-243812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_243901-243912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_244001-244012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_244101-244112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_244201-244212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_244301-244312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_244401-244412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_244501-244512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_244601-244612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_244701-244712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_244801-244812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_244901-244912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_245001-245012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_245101-245112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_245201-245212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_245301-245312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_245401-245412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_245501-245512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_245601-245612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_245701-245712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_245801-245812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_245901-245912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_246001-246012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_246101-246112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_246201-246212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_246301-246312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_246401-246412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_246501-246512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_246601-246612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_246701-246712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_246801-246812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_246901-246912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_247001-247012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_247101-247112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_247201-247212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_247301-247312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_247401-247412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_247501-247512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_247601-247612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_247701-247712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_247801-247812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_247901-247912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_248001-248012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_248101-248112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_248201-248212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_248301-248312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_248401-248412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_248501-248512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_248601-248612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_248701-248712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_248801-248812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_248901-248912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_249001-249012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_249101-249112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_249201-249212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_249301-249312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_249401-249412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_249501-249512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_249601-249612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_249701-249712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_249801-249812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_249901-249912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_250001-250012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_250101-250112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_250201-250212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_250301-250312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_250401-250412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_250501-250512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_250601-250612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_250701-250712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_250801-250812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_250901-250912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_251001-251012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_251101-251112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_251201-251212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_251301-251312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_251401-251412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_251501-251512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_251601-251612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_251701-251712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_251801-251812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_251901-251912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_252001-252012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_252101-252112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_252201-252212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_252301-252312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_252401-252412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_252501-252512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_252601-252612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_252701-252712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_252801-252812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_252901-252912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_253001-253012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_253101-253112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_253201-253212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_253301-253312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_253401-253412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_253501-253512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_253601-253612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_253701-253712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_253801-253812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_253901-253912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_254001-254012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_254101-254112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_254201-254212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_254301-254312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_254401-254412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_254501-254512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_254601-254612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_254701-254712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_254801-254812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_254901-254912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_255001-255012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_255101-255112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_255201-255212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_255301-255312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_255401-255412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_255501-255512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_255601-255612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_255701-255712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_255801-255812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_255901-255912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_256001-256012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_256101-256112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_256201-256212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_256301-256312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_256401-256412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_256501-256512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_256601-256612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_256701-256712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_256801-256812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_256901-256912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_257001-257012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_257101-257112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_257201-257212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_257301-257312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_257401-257412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_257501-257512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_257601-257612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_257701-257712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_257801-257812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_257901-257912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_258001-258012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_258101-258112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_258201-258212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_258301-258312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_258401-258412.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_258501-258512.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_258601-258612.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_258701-258712.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_258801-258812.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_258901-258912.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_259001-259012.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_259101-259112.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_259201-259212.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_259301-259312.nc
# ps_Amon_EC-Earth3_piControl_r1i1p1f1_gr_259401-259412.nc
# ...
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_016101-017012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_017101-018012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_018101-019012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_019101-020012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_020101-021012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_021101-022012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_022101-023012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_023101-024012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_024101-025012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_025101-026012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_026101-027012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_027101-028012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_028101-029012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_029101-030012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_030101-031012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_031101-032012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_032101-033012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_033101-034012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_034101-035012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_035101-036012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_036101-037012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_037101-038012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_038101-039012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_039101-040012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_040101-041012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_041101-042012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_042101-043012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_043101-044012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_044101-045012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_045101-046012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_046101-047012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_047101-048012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_048101-049012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_049101-050012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_050101-051012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_051101-052012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_052101-053012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_053101-054012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_054101-055012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_055101-056012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_056101-057012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_057101-058012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_058101-059012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_059101-060012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_060101-061012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_061101-062012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_062101-063012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_063101-064012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_064101-065012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_065101-066012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_066101-067012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_067101-068012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_068101-069012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_069101-070012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_000101-001012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_001101-002012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_002101-003012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_003101-004012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_004101-005012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_005101-006012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_006101-007012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_007101-008012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_008101-009012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_009101-010012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_010101-011012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_011101-012012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_012101-013012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_013101-014012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_014101-015012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_015101-016012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_016101-017012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_017101-018012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_018101-019012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_019101-020012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_020101-021012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_021101-022012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_022101-023012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_023101-024012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_024101-025012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_025101-026012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_026101-027012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_027101-028012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_028101-029012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_029101-030012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_030101-031012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_031101-032012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_032101-033012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_033101-034012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_034101-035012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_035101-036012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_036101-037012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_037101-038012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_038101-039012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_039101-040012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_040101-041012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_041101-042012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_042101-043012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_043101-044012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_044101-045012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_045101-046012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_046101-047012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_047101-048012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_048101-049012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_049101-050012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_050101-051012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_051101-052012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_052101-053012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_053101-054012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_054101-055012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_055101-056012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_056101-057012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_057101-058012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_058101-059012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_059101-060012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_060101-061012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_061101-062012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_062101-063012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_063101-064012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_064101-065012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_065101-066012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_066101-067012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_067101-068012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_068101-069012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_069101-070012.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_185001-185912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_186001-186912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_187001-187912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_188001-188912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_189001-189912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_190001-190912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_191001-191912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_192001-192912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_193001-193912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_194001-194912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_195001-195912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_196001-196912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_197001-197912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_198001-198912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_199001-199912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_185001-185912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_186001-186912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_187001-187912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_188001-188912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_189001-189912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_190001-190912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_191001-191912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_192001-192912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_193001-193912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_194001-194912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_195001-195912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_196001-196912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_197001-197912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_198001-198912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_199001-199912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_185001-185912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_186001-186912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_187001-187912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_188001-188912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_189001-189912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_190001-190912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_191001-191912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_192001-192912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_193001-193912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_194001-194912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_195001-195912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_196001-196912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_197001-197912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_198001-198912.nc
# ps_Amon_SAM0-UNICON_abrupt-4xCO2_r1i1p1f1_gn_199001-199912.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_000101-001012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_001101-002012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_002101-003012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_003101-004012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_004101-005012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_005101-006012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_006101-007012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_007101-008012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_008101-009012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_009101-010012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_010101-011012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_011101-012012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_012101-013012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_013101-014012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_014101-015012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_015101-016012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_016101-017012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_017101-018012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_018101-019012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_019101-020012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_020101-021012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_021101-022012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_022101-023012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_023101-024012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_024101-025012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_025101-026012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_026101-027012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_027101-028012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_028101-029012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_029101-030012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_030101-031012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_031101-032012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_032101-033012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_033101-034012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_034101-035012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_035101-036012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_036101-037012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_037101-038012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_038101-039012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_039101-040012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_040101-041012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_041101-042012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_042101-043012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_043101-044012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_044101-045012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_045101-046012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_046101-047012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_047101-048012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_048101-049012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_049101-050012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_050101-051012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_051101-052012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_052101-053012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_053101-054012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_054101-055012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_055101-056012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_056101-057012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_057101-058012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_058101-059012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_059101-060012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_060101-061012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_061101-062012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_062101-063012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_063101-064012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_064101-065012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_065101-066012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_066101-067012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_067101-068012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_068101-069012.nc
# ps_Amon_SAM0-UNICON_piControl_r1i1p1f1_gn_069101-070012.nc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 13
#       9         notIn.append(model)
#      10 df['timeStep'] = 'mon'
# ---> 13 df[['start', 'stop']] = df['filename'].apply(lambda x: pd.Series(extractDates(x)))
#      14 df.to_csv(f'CO2_4x_url_all_psMon.csv', index=None)
#      15 # --------------------------------------------------------
#
# File /opt/jaspy/lib/python3.11/site-packages/pandas/core/frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File /opt/jaspy/lib/python3.11/site-packages/pandas/core/frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# -> 4341         check_key_length(self.columns, key, value)
#    4342         for k1, k2 in zip(key, value.columns):
#    4343             self[k1] = value[k2]
#
# File /opt/jaspy/lib/python3.11/site-packages/pandas/core/indexers/utils.py:390, in check_key_length(columns, key, value)
#     388 if columns.is_unique:
#     389     if len(value.columns) != len(key):
# --> 390         raise ValueError("Columns must be same length as key")
#     391 else:
#     392     # Missing keys in columns are represented as -1
#     393     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %% [markdown]
# #### 4: Quality controlling CO2_4x_url_all_psMon - to make sure they all are what we'd expect them to be

# %%
df = pd.read_csv('CO2_4x_url_usable_wMon.csv', index_col=0)
pd.set_option('display.max_rows', 400)

df.query("period == 'abrupt-4xCO2' & Var == 'huss' & openDapWorking").filename.unique()
def extractDates(string):
    ncFind = string.find('.nc') 
    ncBack = string.rfind('-', 0, ncFind)
    dback = (ncFind-ncBack)-1
    stop = string[ncBack+1:ncFind]
    start = string[ncBack-dback:ncBack]
    try:
        return extractYear(start), extractYear(stop)
    except:
        print(string)
def extractYear(Date):
    return int(Date[:4])

# figure out the time each models cover
df[['start', 'stop']] = df['filename'].apply(extractDates).apply(pd.Series)

# for each variable - what is the minimum and maximum times they cover
stopMax = df.groupby(['model', 'period', 'Var'], as_index=False).stop.max()
startMin = df.groupby(['model', 'period', 'Var'], as_index=False).start.min()

# find the overlaping times shared for each model and period
stopShared = stopMax.groupby(['model', 'period'], as_index=False).min()
startShared = startMin.groupby(['model', 'period'], as_index=False).max()

span_df = pd.DataFrame({'model': startShared.model, 
              'period': startShared.period, 
              'span': stopShared.stop - startShared.start,
              'startShared': startShared.start,
              'stopShared': stopShared.stop})

# find models that don't have shared data that spans more than 20 years
insufficientSpan = []
for model in span_df.model.unique():
    spans = span_df[span_df['model'] == model].span.to_numpy()
    if any(v < 20 for v in spans):
        insufficientSpan.append(model)

print('the following models dont cover a shared 20 years: ', insufficientSpan)

# remove models with insufficient span
df = df[~df.model.isin(insufficientSpan)]

def inspan(row, padstart, padend):
    return max(row['start'], padstart) <= min(row['stop'], padend)

dfs = []  # Store results for all models and periods
i = 0 
for model in df.model.unique():
    for period in df.period.unique():
        i+=1
        # Calculate padstart and padend based on `span_df`
        mask = (span_df.model == model) & (span_df.period == period)
        if mask.sum() > 0:  # Ensure there's a match in span_df
            end = int(span_df.loc[mask, 'stopShared'].iloc[0])  # Extract the scalar value safely
            padend = end + 3
            padstart = end - 20 - 3
            
            filtered_df = df[(df.model == model) & (df.period == period)].copy()

            # Apply inspan to the filtered DataFrame
            filtered_df.loc[:, 'inspan'] = filtered_df.apply(
                lambda row: inspan(row, padstart, padend), axis=1
            )
            
            dfs.append(filtered_df)

df = pd.concat(dfs, ignore_index=True)
print(len(df.model.unique()))
df = df[df.inspan].reset_index(drop=True)
print(len(df.model.unique()))
span_df = span_df[~span_df.model.isin(insufficientSpan)].reset_index(drop = True)
span_df.to_csv('span_df.csv')
df.to_csv('CO2_4x_url_reduced_wMon.csv', index=None)
# Out:
# the following models dont cover a shared 20 years:  ['EC-Earth3-Veg', 'MRI-ESM2-0']
# 29
# 29

# %% [markdown]
# #### 5: Adding this into the CO2_4x_url_usable
# Have to add a column for if its a monthly or daily var - along with some logic

# %% [markdown]
# #### 6: integrated retrevial function for open_dap links
# This is what we'll use in the preprocessing steps
